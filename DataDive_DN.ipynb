# %%
import pandas as pd
import numpy as np
from data_dict import get_data_dictionary
import requests
from bs4 import BeautifulSoup
pd.set_option('max_columns', 150)
pd.set_option('max_rows', 110)

# %%
folder = 'Health'
name = 'sect3_hh_w4'

# %%
data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/socio-economic survey 2018-2019/'+folder+'/'+name+'.csv')
# Out:
# /Library/Python/3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (0,28,37,63,68) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_dict = get_data_dictionary(name)

# %%
data_dict
# Out:
#             label                                               desc
# 0    household_id                       Unique Household Indentifier
# 1   individual_id                                Household member ID
# 2           ea_id                Unique Enumeration Area Indentifier
# 3           saq14                                        Rural/Urban
# 4           pw_w4                       Final adjusted wave 4 weight
# 5           saq01                                        Region code
# 6           saq02                                          Zone Code
# 7           saq03                                        Woreda Code
# 8           saq04                                          City Code
# 9           saq05                                      Sub city code
# 10          saq06                                        Kebele Code
# 11          saq07                                            EA code
# 12          saq08                                       Household ID
# 13          s3q01       1. IS [NAME] ANSWERING FOR HIMSELF/ HERSELF?
# 14          s3q02                   2. WHO IS RESPONDING FOR [NAME]?
# 15          s3q03  3. Has [NAME] visited a health centre in the l...
# 16        s3q04_1         4. What was the reason for [NAME]'s visit?
# 17        s3q04_2         4. What was the reason for [NAME]'s visit?
# 18       s3q04_os                                      4_Oth. Reason
# 19          s3q05  5. During the last 4 weeks, did [NAME] suffer ...
# 20        s3q06_1  6. What type of illness/injury did [NAME] suff...
# 21        s3q06_2  6. What type of illness/injury did [NAME] suff...
# 22       s3q06_os     6_Oth. Please specify the other illness/injury
# 23          s3q07  7. [NAME] had to stop usual activities because...
# 24          s3q08  8. Number of days [NAME] had to stop usual act...
# 25         s3q09a         9a. Whom did [NAME] consult for illness 1?
# 26      s3q09a_os                             9a_oth. Please specify
# 27         s3q09b         9b. Whom did [NAME] consult for illness 2?
# 28      s3q09b_os                             9b_oth. Please specify
# 29         s3q10a  10a.Where did [NAME] consultation take place f...
# 30      s3q10a_os   10a_oth. Specify the other type of establishment
# 31         s3q10b  10b. Where did [NAME] consultation take place ...
# 32      s3q10b_os   10b_oth. Specify the other type of establishment
# 33          s3q11  11.How much did [NAME] pay for the first consu...
# 34         s3q12a  12a.How long did [NAME]'s first consultation t...
# 35         s3q12b  12b.How long did [NAME]'s first consultation t...
# 36          s3q13  13. Main reason for [NAME] not consulting a he...
# 37       s3q13_os                   13_oth. Specify the other reason
# 38          s3q14  14. [NAME] consulted a healthcare provider in ...
# 39          s3q15  15. Number of times [NAME] consulted a healthc...
# 40          s3q16  16. Were any of [NAME]'s consultations inpatie...
# 41          s3q17  17. How many nights did [NAME] spend in any he...
# 42          s3q18  18. What were the total cost of [NAME]'s healt...
# 43          s3q19  19. Type of health insurance [NAME] is current...
# 44          s3q20              20. IS [NAME] AGED 6 YEARS AND OLDER?
# 45          s3q21  21. Does [NAME] have difficulty seeing, even i...
# 46          s3q22  22. [NAME] has difficulty hearing, even if wea...
# 47          s3q23  23. Does [NAME] have difficulty walking or cli...
# 48          s3q24  24. Does [NAME] have difficulty remembering or...
# 49          s3q25           25. [NAME] has difficulty with self care
# 50          s3q26  26. [NAME] has difficulty communicating using ...
# 51          s3q27  27. IS [NAME] AGED 6 MONTHS OR OLDER AND YOUNG...
# 52          s3q28  28. Has [NAME] had diarrhea in the last two we...
# 53          s3q29  29. How much water was [NAME] offered to drink...
# 54         s3q30a        30a. [NAME] was given Oral Rehydration Salt
# 55         s3q30b  30b. [NAME] was given fluid recommended by hea...
# 56          s3q31                     31. Was [NAME] ever breastfed?
# 57          s3q32  32. Since the time of birth, for how many mont...
# 58          s3q33  33. Number of months [NAME]Â exclusivelyÂ brea...
# 59        s3q34_a            34a. Day of birth in Ethiopian calendar
# 60        s3q34_b          34b. Month of birth in Ethiopian calendar
# 61        s3q34_c           34c. Year of birth in Ethiopian calendar
# 62          s3q35  35. WHAT IS THE SOURCE OF DATE OF BIRTH INFORM...
# 63       s3q35_os                   35_oth. Specify the other reason
# 64          s3q36                           36. WAS [NAME] MEASURED?
# 65          s3q37                  37. WEIGHT OF [NAME] IN KILOGRAMS
# 66          s3q38                38. WEIGHT OF [NAME] IN CENTIMETERS
# 67          s3q39                   39. WHY WAS [NAME] NOT MEASURED?
# 68       s3q39_os                   39_oth. Specify the other reason

# %%
data
# Out:
#              household_id  individual_id            ea_id     saq14  \
# 0      010101088800910007              1   10101088800910  1. RURAL
# 1      010101088800910007              2   10101088800910  1. RURAL
# 2      010101088800910007              3   10101088800910  1. RURAL
# 3      010101088800910007              4   10101088800910  1. RURAL
# 4      010101088800910007              5   10101088800910  1. RURAL
# ...                   ...            ...              ...       ...
# 29498  150101088803701097              1  150101088803701  1. RURAL
# 29499  150101088803701097              2  150101088803701  1. RURAL
# 29500  150101088803701097              3  150101088803701  1. RURAL
# 29501  150101088803701097              4  150101088803701  1. RURAL
# 29502  150101088803701097              5  150101088803701  1. RURAL
#
#              pw_w4          saq01  saq02  saq03  saq04  saq05  saq06  saq07  \
# 0      1658.475109      1. TIGRAY      1      1      8     88      9     10
# 1      1658.475109      1. TIGRAY      1      1      8     88      9     10
# 2      1658.475109      1. TIGRAY      1      1      8     88      9     10
# 3      1658.475109      1. TIGRAY      1      1      8     88      9     10
# 4      1658.475109      1. TIGRAY      1      1      8     88      9     10
# ...            ...            ...    ...    ...    ...    ...    ...    ...
# 29498   210.761706  15. DIRE DAWA      1      1      8     88     37      1
# 29499   210.761706  15. DIRE DAWA      1      1      8     88     37      1
# 29500   210.761706  15. DIRE DAWA      1      1      8     88     37      1
# 29501   210.761706  15. DIRE DAWA      1      1      8     88     37      1
# 29502   210.761706  15. DIRE DAWA      1      1      8     88     37      1
#
#        saq08   s3q01  s3q02  s3q03 s3q04_1 s3q04_2 s3q04_os   s3q05  \
# 0        7.0  1. YES    NaN  2. NO     NaN     NaN      NaN  1. YES
# 1        7.0  1. YES    NaN  2. NO     NaN     NaN      NaN   2. NO
# 2        7.0  1. YES    NaN  2. NO     NaN     NaN      NaN   2. NO
# 3        7.0     NaN    NaN    NaN     NaN     NaN      NaN     NaN
# 4        7.0   2. NO    1.0  2. NO     NaN     NaN      NaN   2. NO
# ...      ...     ...    ...    ...     ...     ...      ...     ...
# 29498   97.0  1. YES    NaN  2. NO     NaN     NaN      NaN   2. NO
# 29499   97.0  1. YES    NaN  2. NO     NaN     NaN      NaN   2. NO
# 29500   97.0   2. NO    1.0  2. NO     NaN     NaN      NaN   2. NO
# 29501   97.0   2. NO    1.0  2. NO     NaN     NaN      NaN   2. NO
# 29502   97.0   2. NO    1.0  2. NO     NaN     NaN      NaN   2. NO
#
#                       s3q06_1             s3q06_2 s3q06_os   s3q07  s3q08  \
# 0      23. ULCER/STOMACH PAIN  28. KIDNEY PROBLEM      NaN  1. YES   10.0
# 1                         NaN                 NaN      NaN     NaN    NaN
# 2                         NaN                 NaN      NaN     NaN    NaN
# 3                         NaN                 NaN      NaN     NaN    NaN
# 4                         NaN                 NaN      NaN     NaN    NaN
# ...                       ...                 ...      ...     ...    ...
# 29498                     NaN                 NaN      NaN     NaN    NaN
# 29499                     NaN                 NaN      NaN     NaN    NaN
# 29500                     NaN                 NaN      NaN     NaN    NaN
# 29501                     NaN                 NaN      NaN     NaN    NaN
# 29502                     NaN                 NaN      NaN     NaN    NaN
#
#           s3q09a s3q09a_os     s3q09b s3q09b_os       s3q10a s3q10a_os  \
# 0      1. DOCTOR       NaN  1. DOCTOR       NaN  1. HOSPITAL       NaN
# 1            NaN       NaN        NaN       NaN          NaN       NaN
# 2            NaN       NaN        NaN       NaN          NaN       NaN
# 3            NaN       NaN        NaN       NaN          NaN       NaN
# 4            NaN       NaN        NaN       NaN          NaN       NaN
# ...          ...       ...        ...       ...          ...       ...
# 29498        NaN       NaN        NaN       NaN          NaN       NaN
# 29499        NaN       NaN        NaN       NaN          NaN       NaN
# 29500        NaN       NaN        NaN       NaN          NaN       NaN
# 29501        NaN       NaN        NaN       NaN          NaN       NaN
# 29502        NaN       NaN        NaN       NaN          NaN       NaN
#
#             s3q10b  s3q10b_os s3q11 s3q12a s3q12b s3q13 s3q13_os   s3q14  \
# 0      1. HOSPITAL        NaN   300      2     30   NaN      NaN  1. YES
# 1              NaN        NaN   NaN    NaN    NaN   NaN      NaN   2. NO
# 2              NaN        NaN   NaN    NaN    NaN   NaN      NaN  1. YES
# 3              NaN        NaN   NaN    NaN    NaN   NaN      NaN     NaN
# 4              NaN        NaN   NaN    NaN    NaN   NaN      NaN  1. YES
# ...            ...        ...   ...    ...    ...   ...      ...     ...
# 29498          NaN        NaN   NaN    NaN    NaN   NaN      NaN   2. NO
# 29499          NaN        NaN   NaN    NaN    NaN   NaN      NaN  1. YES
# 29500          NaN        NaN   NaN    NaN    NaN   NaN      NaN   2. NO
# 29501          NaN        NaN   NaN    NaN    NaN   NaN      NaN  1. YES
# 29502          NaN        NaN   NaN    NaN    NaN   NaN      NaN  1. YES
#
#        s3q15   s3q16  s3q17         s3q18                           s3q19  \
# 0        4.0  1. YES   10.0          1300  4. DON'T HAVE HEALTH INSURANCE
# 1        NaN     NaN    NaN           NaN  4. DON'T HAVE HEALTH INSURANCE
# 2        3.0   2. NO    NaN           800  4. DON'T HAVE HEALTH INSURANCE
# 3        NaN     NaN    NaN           NaN                             NaN
# 4        2.0   2. NO    NaN           300  4. DON'T HAVE HEALTH INSURANCE
# ...      ...     ...    ...           ...                             ...
# 29498    NaN     NaN    NaN           NaN  4. DON'T HAVE HEALTH INSURANCE
# 29499    2.0   2. NO    NaN           200  4. DON'T HAVE HEALTH INSURANCE
# 29500    NaN     NaN    NaN           NaN  4. DON'T HAVE HEALTH INSURANCE
# 29501    4.0   2. NO    NaN  0. áˆáŠ•áˆ  4. DON'T HAVE HEALTH INSURANCE
# 29502    3.0   2. NO    NaN           500  4. DON'T HAVE HEALTH INSURANCE
#
#         s3q20             s3q21                         s3q22  \
# 0      1. YES  1. NO DIFFICULTY  3. YES - A LOT OF DIFFICULTY
# 1      1. YES  1. NO DIFFICULTY      2. YES - SOME DIFFICULTY
# 2      1. YES  1. NO DIFFICULTY              1. NO DIFFICULTY
# 3         NaN               NaN                           NaN
# 4      1. YES  1. NO DIFFICULTY              1. NO DIFFICULTY
# ...       ...               ...                           ...
# 29498  1. YES  1. NO DIFFICULTY              1. NO DIFFICULTY
# 29499  1. YES  1. NO DIFFICULTY              1. NO DIFFICULTY
# 29500  1. YES  1. NO DIFFICULTY              1. NO DIFFICULTY
# 29501   2. NO               NaN                           NaN
# 29502   2. NO               NaN                           NaN
#
#                   s3q23             s3q24                     s3q25  \
# 0      1. NO DIFFICULTY  1. NO DIFFICULTY          1. NO DIFFICULTY
# 1      1. NO DIFFICULTY  1. NO DIFFICULTY  2. YES - SOME DIFFICULTY
# 2      1. NO DIFFICULTY  1. NO DIFFICULTY          1. NO DIFFICULTY
# 3                   NaN               NaN                       NaN
# 4      1. NO DIFFICULTY  1. NO DIFFICULTY          1. NO DIFFICULTY
# ...                 ...               ...                       ...
# 29498  1. NO DIFFICULTY  1. NO DIFFICULTY          1. NO DIFFICULTY
# 29499  1. NO DIFFICULTY  1. NO DIFFICULTY          1. NO DIFFICULTY
# 29500  1. NO DIFFICULTY  1. NO DIFFICULTY          1. NO DIFFICULTY
# 29501               NaN               NaN                       NaN
# 29502               NaN               NaN                       NaN
#
#                           s3q26   s3q27   s3q28               s3q29  s3q30a  \
# 0      2. YES - SOME DIFFICULTY   2. NO     NaN                 NaN     NaN
# 1              1. NO DIFFICULTY   2. NO     NaN                 NaN     NaN
# 2              1. NO DIFFICULTY   2. NO     NaN                 NaN     NaN
# 3                           NaN     NaN     NaN                 NaN     NaN
# 4              1. NO DIFFICULTY   2. NO     NaN                 NaN     NaN
# ...                         ...     ...     ...                 ...     ...
# 29498          1. NO DIFFICULTY   2. NO     NaN                 NaN     NaN
# 29499          1. NO DIFFICULTY   2. NO     NaN                 NaN     NaN
# 29500          1. NO DIFFICULTY   2. NO     NaN                 NaN     NaN
# 29501                       NaN  1. YES   2. NO                 NaN     NaN
# 29502                       NaN  1. YES  1. YES  1. LESS THAN USUAL  1. YES
#
#       s3q30b                 s3q31  s3q32 s3q33  s3q34_a  s3q34_b  s3q34_c  \
# 0        NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# 1        NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# 2        NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# 3        NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# 4        NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# ...      ...                   ...    ...   ...      ...      ...      ...
# 29498    NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# 29499    NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# 29500    NaN                   NaN    NaN   NaN      NaN      NaN      NaN
# 29501    NaN  2. YES,BUT NO LONGER   16.0     6     21.0      3.0   2008.0
# 29502  2. NO  2. YES,BUT NO LONGER   22.0     6     15.0      3.0   2009.0
#
#                     s3q35 s3q35_os   s3q36  s3q37  s3q38 s3q39 s3q39_os
# 0                     NaN      NaN     NaN    NaN    NaN   NaN      NaN
# 1                     NaN      NaN     NaN    NaN    NaN   NaN      NaN
# 2                     NaN      NaN     NaN    NaN    NaN   NaN      NaN
# 3                     NaN      NaN     NaN    NaN    NaN   NaN      NaN
# 4                     NaN      NaN     NaN    NaN    NaN   NaN      NaN
# ...                   ...      ...     ...    ...    ...   ...      ...
# 29498                 NaN      NaN     NaN    NaN    NaN   NaN      NaN
# 29499                 NaN      NaN     NaN    NaN    NaN   NaN      NaN
# 29500                 NaN      NaN     NaN    NaN    NaN   NaN      NaN
# 29501  4. PARENT RESPONSE      NaN  1. YES   8.50   81.0   NaN      NaN
# 29502  4. PARENT RESPONSE      NaN  1. YES  16.58   85.0   NaN      NaN
#
# [29503 rows x 69 columns]

# %%
food_data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/Predicting_Food_Crises_Data/predicting_food_crises_data.csv')

# %% [markdown]
# Is there a way to match `admin_name` with woreda or kebele?

# %%
set(food_data[food_data.country == 'Ethiopia'].admin_name)

# %%
wash_data = pd.read_excel('~/Desktop/Mar21-humanitarian-data/data/WASH_Data/JMP_2019_INEQUALITIES_ETH_Ethiopia.xlsm')

# %%
wash_data.head()

# %%
covid_data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/COVID-19 High Frequency Phone Survey of Households 2020/r1_wb_lsms_hfpm_hh_survey_public_microdata.csv')

# %%
list(covid_data.columns)

# %%
#Grab the page
page = requests.get()
soup = BeautifulSoup(page.text, 'html.parser')
mydivs = soup.find_all("div", {"class": "table-variable-list"})

#Now build the data dictionary
data_dictionary = []
for row in mydivs[0].find_all('div', {"class": 'var-row'}):
    col_data = [i.text.strip() for i in row.find_all('a')]
    data_dictionary.append(col_data)
data_dictionary_df = pd.DataFrame(data_dictionary, columns=['label', 'desc'])

# %%
page

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
lis = soup.find_all("li", {"class": "nada-list-group-item"})

# %%
type(lis[1].find_all('a')[0].text)

# %%
for i in range(1, len(lis)-1):
    if name in lis[i].find_all('a')[0].text:
        url = lis[i].find_all('a')[0].attrs['href']
        break

# %%
len(lis)

# %%
lis[68]

# %%
url

# %%
mali_data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/Mali_Data/indicator_data_ml.csv')

# %%
mali_data[mali_data.year == '2025']
