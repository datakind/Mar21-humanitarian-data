# %%
import pandas as pd
import numpy as np
from data_dict import get_data_dictionary
import requests
from bs4 import BeautifulSoup

# %%
name = 'sect10_ph_w4'

# %%
data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/socio-economic survey 2018-2019/Financial services-labor-economic opportunity/'+name+'.csv')
# Out:
# /Library/Python/3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_dict = get_data_dictionary(name)

# %%
data_dict
# Out:
#            label                                               desc
# 0      holder_id                          Unique Holder Indentifier
# 1   household_id                       Unique Household Indentifier
# 2      parcel_id                           Unique Parcel Identifier
# 3       field_id                            Unique Field Identifier
# 4        crop_id                             Unique Crop Identifier
# 5          ea_id                Unique Enumeration Area Indentifier
# 6          saq14              14. Location: rural, town, small town
# 7          pw_w4                       Final adjusted wave 4 weight
# 8          saq01                                        Region code
# 9          saq02                                          Zone Code
# 10         saq03                                        Woreda Code
# 11         saq04                                          City Code
# 12         saq05                                      Sub city code
# 13         saq06                                        Kebele Code
# 14         saq07                                            EA code
# 15         saq08                                       Household ID
# 16         saq09                                          Holder ID
# 17         saq15                15. What is the holder's farm type?
# 18         s9q01                               Roster list question
# 19        s9q00b                                        1.Crop code
# 20       s10q01a                       1a.Hired Men (Number of Men)
# 21       s10q01b                      1b.Hired Men (Number of Days)
# 22       s10q01c               1c.Hired Men (Total Daily Wage BIRR)
# 23       s10q01d                   1d.Hired Women (Number of Women)
# 24       s10q01e                    1e.Hired Women (Number of Days)
# 25       s10q01f             1f.Hired Women (Total Daily Wage BIRR)
# 26       s10q01g             1g.Hired Children (Number of Children)
# 27       s10q01h                 1h.Hired Children (Number of Days)
# 28       s10q01i          1i.Hired Children (Total Daily Wage BIRR)
# 29        s10q02  2.How many HH members worked on the harvesting...
# 30       s10q02a  2a.HH Member #1 working on field (HH Roster ID...
# 31       s10q02b           2b.HH Member #1 working on field (Weeks)
# 32       s10q02c       2c.HH Member #1 working on field (Days/Week)
# 33       s10q02d       29d.HH Member #1 working on field (Hour/Day)
# 34       s10q02e  2e.HH Member #2 working on field (HH Roster ID...
# 35       s10q02f           2f.HH Member #2 working on field (Weeks)
# 36       s10q02g       2g.HH Member #2 working on field (Days/Week)
# 37       s10q02h        2h.HH Member #2 working on field (Hour/Day)
# 38       s10q02i  2i.HH Member #3 working on field (HH Roster ID...
# 39       s10q02j           2j.HH Member #3 working on field (Weeks)
# 40       s10q02k       2k.HH Member #3 working on field (Days/Week)
# 41       s10q02l        2l.HH Member #3 working on field (Hour/Day)
# 42       s10q02m  2m.HH Member #4 working on field (HH Roster ID...
# 43       s10q02n           2n.HH Member #4 working on field (Weeks)
# 44       s10q02o       2o.HH Member #4 working on field (Days/Week)
# 45       s10q02p        2p.HH Member #4 working on field (Hour/Day)
# 46       s10q03a                 3a.Other HH Labour (Number of Men)
# 47       s10q03b            3b.Other HH Labour (Men Number of Days)
# 48       s10q03c               3c.Other HH Labour (Number of Women)
# 49       s10q03d          3d.Other HH Labour (Women Number of Days)
# 50       s10q03e            3e.Other HH Labour (Number of Children)
# 51       s10q03f       3f.Other HH Labour (Children Number of Days)
# 52        s10q04  4.Did you use any machinary to harvest [CROP] ...
# 53        s10q05  5.If rented machineray used, how much have you...
# 54        s10q06  6.How much did HH spend for other harvest rela...

# %%
data
# Out:
#              household_id                                          source_cd  \
# 0      010101088800910007          101. Cash Transfer/Gifts from Individuals
# 1      010101088800910007         102. Food Transfers/Gifts from Individuals
# 2      010101088800910007  103. Non-food In-kind Transfers/Gifts form Ind...
# 3      010101088800910007  104. Savings, Interest or Other Investment Income
# 4      010101088800910007                                105. Pension Income
# ...                   ...                                                ...
# 94775  150101088803701097                 110. Income from Real Estate Sales
# 94776  150101088803701097  111. Income from household Non-Agricultural As...
# 94777  150101088803701097  112. Income from household Agricultural/Fishin...
# 94778  150101088803701097  113. Income from sales of other Fixed Assets (...
# 94779  150101088803701097         114. Inheritance/Lottery/Gambling Winnings
#
#                  ea_id     saq14        pw_w4          saq01  saq02  saq03  \
# 0       10101088800910  1. RURAL  1658.475109      1. TIGRAY      1      1
# 1       10101088800910  1. RURAL  1658.475109      1. TIGRAY      1      1
# 2       10101088800910  1. RURAL  1658.475109      1. TIGRAY      1      1
# 3       10101088800910  1. RURAL  1658.475109      1. TIGRAY      1      1
# 4       10101088800910  1. RURAL  1658.475109      1. TIGRAY      1      1
# ...                ...       ...          ...            ...    ...    ...
# 94775  150101088803701  1. RURAL   210.761706  15. DIRE DAWA      1      1
# 94776  150101088803701  1. RURAL   210.761706  15. DIRE DAWA      1      1
# 94777  150101088803701  1. RURAL   210.761706  15. DIRE DAWA      1      1
# 94778  150101088803701  1. RURAL   210.761706  15. DIRE DAWA      1      1
# 94779  150101088803701  1. RURAL   210.761706  15. DIRE DAWA      1      1
#
#        saq04  saq05  ...  saq07  saq08  s13q01  s13q02  s13q03_1  s13q03_2  \
# 0          8     88  ...     10    7.0  1. YES  1400.0       1.0       NaN
# 1          8     88  ...     10    7.0  1. YES   500.0       1.0       NaN
# 2          8     88  ...     10    7.0   2. NO     NaN       NaN       NaN
# 3          8     88  ...     10    7.0   2. NO     NaN       NaN       NaN
# 4          8     88  ...     10    7.0   2. NO     NaN       NaN       NaN
# ...      ...    ...  ...    ...    ...     ...     ...       ...       ...
# 94775      8     88  ...      1   97.0   2. NO     NaN       NaN       NaN
# 94776      8     88  ...      1   97.0   2. NO     NaN       NaN       NaN
# 94777      8     88  ...      1   97.0   2. NO     NaN       NaN       NaN
# 94778      8     88  ...      1   97.0   2. NO     NaN       NaN       NaN
# 94779      8     88  ...      1   97.0   2. NO     NaN       NaN       NaN
#
#        s13q04a  s13q04b  s13q04c             s13q05
# 0        400.0   1000.0      0.0  1. INPERSON/ CASH
# 1        500.0      0.0      0.0                NaN
# 2          NaN      NaN      NaN                NaN
# 3          NaN      NaN      NaN                NaN
# 4          NaN      NaN      NaN                NaN
# ...        ...      ...      ...                ...
# 94775      NaN      NaN      NaN                NaN
# 94776      NaN      NaN      NaN                NaN
# 94777      NaN      NaN      NaN                NaN
# 94778      NaN      NaN      NaN                NaN
# 94779      NaN      NaN      NaN                NaN
#
# [94780 rows x 21 columns]

# %%
food_data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/Predicting_Food_Crises_Data/predicting_food_crises_data.csv')

# %% [markdown]
# Is there a way to match `admin_name` with woreda or kebele?

# %%
set(food_data[food_data.country == 'Ethiopia'].admin_name)
# Out:
# {'Addis Adaba',
#  'Afder',
#  'Agnuak',
#  'Alaba',
#  'Arsi',
#  'Asosa',
#  'Awi/Agew',
#  'Awusi',
#  'Bale.1',
#  'Basketo',
#  'Bench Maji',
#  'Borena',
#  'Central Tigray',
#  'Dawro',
#  'Dire Dawa',
#  'Doolo',
#  'East Gojam',
#  'East Harerge',
#  'East Shewa',
#  'East Wellega',
#  'Eastern Tigray',
#  'Fafan',
#  'Fanti',
#  'Gabi',
#  'Gamo Gofa',
#  'Gedio',
#  'Guji',
#  'Gurage',
#  'Hadiya',
#  'Hareri',
#  'Horo Guduru',
#  'Ilubabor',
#  'Jarar',
#  'Jimma',
#  'KT',
#  'Keffa',
#  'Kelem Wellega',
#  'Kemashi',
#  'Khari',
#  'Kilbati',
#  'Konta',
#  'Korahe',
#  'Liben',
#  'Majang',
#  'Metekel',
#  'Nogob',
#  'North Gonder',
#  'North Shewa(R3)',
#  'North Shewa(R4)',
#  'North Western Tigray',
#  'North Wollo',
#  'Nuer',
#  'Oromia',
#  "Segen Peoples'",
#  'Selti',
#  'Shabelle',
#  'Sheka',
#  'Sidama',
#  'Siti',
#  'South Gonder',
#  'South Omo',
#  'South West Shewa',
#  'South Wollo',
#  'Southern Tigray',
#  'Special Woreda',
#  'Wag Himra',
#  'West Arsi',
#  'West Gojam',
#  'West Harerge',
#  'West Shewa',
#  'West Wellega',
#  'Western Tigray',
#  'Wolayita',
#  'Yem'}

# %%
wash_data = pd.read_excel('~/Desktop/Mar21-humanitarian-data/data/WASH_Data/JMP_2019_INEQUALITIES_ETH_Ethiopia.xlsm')

# %%
wash_data.head()
# Out:
#    Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0         NaN         NaN                                                NaN
# 1         NaN         NaN                                                NaN
# 2         NaN         NaN  Joint Monitoring Programme for Water Supply, S...
# 3         NaN         NaN                                                NaN
# 4         NaN         NaN  Estimates on household water, sanitation and h...
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0         NaN          NaN         NaN          NaN          NaN          NaN
# 1         NaN          NaN         NaN          NaN          NaN          NaN
# 2         NaN          NaN         NaN          NaN          NaN          NaN
# 3         NaN          NaN         NaN          NaN          NaN          NaN
# 4         NaN          NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
covid_data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/COVID-19 High Frequency Phone Survey of Households 2020/r1_wb_lsms_hfpm_hh_survey_public_microdata.csv')

# %%
list(covid_data.columns)
# Out:
# ['household_id',
#  'ii4_resp_id',
#  'phw1',
#  'cs4_sector',
#  'cs5_eaid',
#  'cs6_hhid',
#  'cs7_hhh_id',
#  'cs1_region',
#  'cs2_zoneid',
#  'cs3_woredaid',
#  'cs3c_cityid',
#  'cs3c_subcityid',
#  'cs3b_kebeleid',
#  'ea_id',
#  'cs_startdate',
#  'cs_submissiondate',
#  'cs7a_hhh_gender',
#  'cs7a_hhh_age',
#  'cs12_round',
#  'ii1_attempt',
#  'bi_locchange',
#  'bi_same_hhh',
#  'kn1_heard',
#  'kn2_meas_handwash',
#  'kn2_meas_handshake',
#  'kn2_meas_maskglove',
#  'kn2_meas_travel',
#  'kn2_meas_stayhome',
#  'kn2_meas_gatherings',
#  'kn2_meas_distance',
#  'kn2_meas_facetouch',
#  'kn3_gov',
#  'kn3_gov_1',
#  'kn3_gov_2',
#  'kn3_gov_3',
#  'kn3_gov_4',
#  'kn3_gov_5',
#  'kn3_gov_6',
#  'kn3_gov_7',
#  'kn3_gov_8',
#  'kn3_gov_9',
#  'kn3_gov_10',
#  'kn3_gov_11',
#  'kn3_gov_12',
#  'kn3_gov_0',
#  'kn3_gov__98',
#  'kn3_gov__99',
#  'kn3_gov__96',
#  'kn3_gov_other',
#  'bh1_handwash',
#  'bh2_handshake',
#  'bh3_gatherings',
#  'ac1_atb_med',
#  'ac2_atb_med_why',
#  'ac2_atb_med_why_other',
#  'ac1_atb_teff',
#  'ac2_atb_teff_why',
#  'ac2_atb_teff_why_other',
#  'ac1_atb_wheat',
#  'ac2_atb_wheat_why',
#  'ac2_atb_wheat_why_other',
#  'ac1_atb_maize',
#  'ac2_atb_maize_why',
#  'ac2_atb_maize_why_other',
#  'ac1_atb_oil',
#  'ac2_atb_oil_why',
#  'ac2_atb_oil_why_other',
#  'ac3_sch_child',
#  'ac4_sch_girls',
#  'ac4_sch_boys',
#  'ac4_2_edu',
#  'ac5_edu_type',
#  'ac5_edu_type_1',
#  'ac5_edu_type_2',
#  'ac5_edu_type_3',
#  'ac5_edu_type_4',
#  'ac5_edu_type_5',
#  'ac5_edu_type__98',
#  'ac5_edu_type__99',
#  'ac5_edu_type__96',
#  'ac5_edu_type_other',
#  'ac6_med',
#  'ac7_med_access',
#  'ac8_med_access_reas',
#  'ac8_med_access_reas_other',
#  'ac9_bank',
#  'em1_work_cur',
#  'em6_work_cur_act',
#  'em6_work_cur_act_other',
#  'em7_work_cur_status',
#  'em7_work_cur_status_other',
#  'em8_work_cur_same',
#  'em9_work_change_why',
#  'em9_work_change_why_other',
#  'em2_work_pre',
#  'em3_work_no_why',
#  'em3_work_no_why_other',
#  'em4_work_pre_act',
#  'em4_work_pre_act_other',
#  'em5_work_pre_status',
#  'em5_work_pre_status_other',
#  'em12_work_cur_able',
#  'em13_work_cur_notable_paid',
#  'em14_work_cur_notable_why',
#  'em14_work_cur_notable_why_other',
#  'em15_bus',
#  'em16_bus_sector',
#  'em16_bus_sector_other',
#  'em17_bus_inc',
#  'em18_bus_inc_low_amt',
#  'em19_bus_inc_low_why',
#  'em19_bus_inc_low_why_1',
#  'em19_bus_inc_low_why_2',
#  'em19_bus_inc_low_why_3',
#  'em19_bus_inc_low_why_4',
#  'em19_bus_inc_low_why_5',
#  'em19_bus_inc_low_why_6',
#  'em19_bus_inc_low_why_7',
#  'em19_bus_inc_low_why__98',
#  'em19_bus_inc_low_why__99',
#  'em19_bus_inc_low_why__96',
#  'em19_bus_inc_low_why_other',
#  'em20_farm',
#  'em21_farm_norm',
#  'em22_farm_norm_why',
#  'em22_farm_norm_why_1',
#  'em22_farm_norm_why_2',
#  'em22_farm_norm_why_3',
#  'em22_farm_norm_why_4',
#  'em22_farm_norm_why_5',
#  'em22_farm_norm_why_6',
#  'em22_farm_norm_why_7',
#  'em22_farm_norm_why__98',
#  'em22_farm_norm_why__99',
#  'em22_farm_norm_why__96',
#  'em22_farm_norm_why_other',
#  'em23_we',
#  'em24_we_layoff',
#  'em25_we_layoff_covid',
#  'lc1_farm',
#  'lc2_farm_chg',
#  'lc1_bus',
#  'lc2_bus_chg',
#  'lc1_we',
#  'lc2_we_chg',
#  'lc1_rem_dom',
#  'lc2_rem_dom_chg',
#  'lc1_rem_for',
#  'lc2_rem_for_chg',
#  'lc1_isp',
#  'lc2_isp_chg',
#  'lc1_pen',
#  'lc2_pen_chg',
#  'lc1_gov',
#  'lc2_gov_chg',
#  'lc1_ngo',
#  'lc2_ngo_chg',
#  'lc1_other',
#  'lc1_other_source',
#  'lc2_other_chg',
#  'lc3_total_chg',
#  'lc4_total_chg_cope',
#  'lc4_total_chg_cope_1',
#  'lc4_total_chg_cope_2',
#  'lc4_total_chg_cope_3',
#  'lc4_total_chg_cope_4',
#  'lc4_total_chg_cope_5',
#  'lc4_total_chg_cope_6',
#  'lc4_total_chg_cope_7',
#  'lc4_total_chg_cope_8',
#  'lc4_total_chg_cope_9',
#  'lc4_total_chg_cope_10',
#  'lc4_total_chg_cope_11',
#  'lc4_total_chg_cope_12',
#  'lc4_total_chg_cope_13',
#  'lc4_total_chg_cope_14',
#  'lc4_total_chg_cope_15',
#  'lc4_total_chg_cope_0',
#  'lc4_total_chg_cope__98',
#  'lc4_total_chg_cope__99',
#  'lc4_total_chg_cope__96',
#  'lc4_total_chg_cope_other',
#  'fi7_outoffood',
#  'fi8_hungrynoteat',
#  'fi6_noteatfullday',
#  'as1_assist_type',
#  'as1_assist_type_1',
#  'as1_assist_type_2',
#  'as1_assist_type_3',
#  'as1_assist_type_0',
#  'as1_assist_type__98',
#  'as1_assist_type__99',
#  'as1_assist_type__96',
#  'as1_assist_type_other',
#  'as3_food_value',
#  'as2_food_psnp',
#  'as4_food_source',
#  'as4_food_source_other',
#  'as3_forwork_value_food',
#  'as3_forwork_value_cash',
#  'as2_forwork_psnp',
#  'as4_forwork_source',
#  'as4_forwork_source_other',
#  'as3_cash_value',
#  'as2_cash_psnp',
#  'as4_cash_source',
#  'as4_cash_source_other',
#  'as3_other_value',
#  'as2_other_psnp',
#  'as4_other_source',
#  'as4_other_source_other',
#  'ir1_endearly',
#  'ir1_whyendearly',
#  'ir1_whyendearly_other',
#  'ir_lang',
#  'ir_understand',
#  'ir_confident',
#  'key']

# %%
#Grab the page
page = requests.get()
soup = BeautifulSoup(page.text, 'html.parser')
mydivs = soup.find_all("div", {"class": "table-variable-list"})

#Now build the data dictionary
data_dictionary = []
for row in mydivs[0].find_all('div', {"class": 'var-row'}):
    col_data = [i.text.strip() for i in row.find_all('a')]
    data_dictionary.append(col_data)
data_dictionary_df = pd.DataFrame(data_dictionary, columns=['label', 'desc'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-6fa8d78ef8c1> in <module>
#       1 #Grab the page
# ----> 2 page = requests.get(url)
#       3 soup = BeautifulSoup(page.text, 'html.parser')
#       4 mydivs = soup.find_all("div", {"class": "table-variable-list"})
#       5
#
# NameError: name 'url' is not defined

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
lis = soup.find_all("li", {"class": "nada-list-group-item"})

# %%
type(lis[1].find_all('a')[0].text)
# Out:
# str

# %%
for i in range(1, len(lis)-1):
    if name in lis[i].find_all('a')[0].text:
        url = lis[i].find_all('a')[0].attrs['href']
        break

# %%
len(lis)
# Out:
# 69

# %%
lis[68]
# Out:
# <li class="nada-list-group-item">
# <a href="https://microdata.worldbank.org/index.php/catalog/3823/data-dictionary/F71?file_name=Food_CF_Wave4.dta">Food_CF_Wave4.dta</a>
# </li>

# %%
url
# Out:
# 'https://microdata.worldbank.org/index.php/catalog/3823/data-dictionary/F65?file_name=sect13_hh_w4_v2.dta'

# %%
mali_data = pd.read_csv('~/Desktop/Mar21-humanitarian-data/data/Mali_Data/indicator_data_ml.csv')

# %%
mali_data[mali_data.year == '2025']
# Out:
#           category                                indicator  \
# 10   Slum dwellers   urban_population_percentage_fewer_500k
# 44      Population               urban_population_countries
# 52      Population       population_cities_by_country_1m_5m
# 188     Population                               population
# 203     Population             number_of_cities_1_5_million
# 223     Population  avg_annual_rate_change_percentage_urban
# 252  Slum dwellers        urban_population_percentage_1m_5m
# 334     Population  avg_annual_rate_change_percentage_total
# 384     Population                         rural_population
#
#                                     indicator_friendly type_data latitude  \
# 10   Percentage of urban population (by country) – ...         p       17
# 44                        Urban population – Countries      1000       17
# 52   Population in cities by country – cities with ...      1000       17
# 188                                   Total population      1000       17
# 203  Number of cities by country – 1 to 5 million i...         n       17
# 223  Average annual rate of change of population – ...         p       17
# 252  Percentage of urban population (by country) – ...         p       17
# 334  Average annual rate of change of population – ...         p       17
# 384                                   Rural population      1000       17
#
#     longitude region_id country_id  name  year  value
# 10         -4       289         ML  Mali  2025  64.24
# 44         -4       289         ML  Mali  2025   8987
# 52         -4       289         ML  Mali  2025   3214
# 188        -4       289         ML  Mali  2025  20589
# 203        -4       289         ML  Mali  2025      1
# 223        -4       289         ML  Mali  2025   1.65
# 252        -4       289         ML  Mali  2025  35.76
# 334        -4       289         ML  Mali  2025   2.43
# 384        -4       289         ML  Mali  2025  11603
